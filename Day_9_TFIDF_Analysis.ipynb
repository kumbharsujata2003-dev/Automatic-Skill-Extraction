# %%
import pandas as pd

# %%
df = pd.read_csv("raw_jobs.csv")

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.monsterindia.com/job/rm-retail-agr...
# 1  https://www.monsterindia.com/job/software-engi...
# 2  https://www.monsterindia.com/job/product-manag...
# 3  https://www.monsterindia.com/job/location-sale...
# 4  https://www.monsterindia.com/job/principal-sof...
#
#                                           title  \
# 0                                RM-Retail Agri
# 1                          Software Engineer II
# 2     Product Manager – Mortgage %26 Retail LAP
# 3  Location Sales Manager-HOUSING FINANCE-Sales
# 4                   Principal Software Engineer
#
#                                          description   posted_at  \
# 0  Job Description : A. Sourcing and Business Gen...  2021-07-27
# 1  Position Type :  Full time   Type Of Hire :  E...  2021-07-23
# 2  About Standard Chartered  We are a leading int...  2021-08-06
# 3  Job Description : Job Role:   To lead a team o...  2021-05-26
# 4  Product Overview Oracle is focused on helping ...  2021-08-06
#
#              crawled_at                                   _id  expires_at  \
# 0  08/13/2021, 01:24:24  fde08100-4d8e-5e15-b206-909e6b84b063  2021-09-25
# 1  08/13/2021, 01:24:24  cae70b5c-30a6-5326-8e21-e68d60ab4af8  2021-09-21
# 2  08/13/2021, 01:24:24  7656f9ad-f78f-5b8d-86c0-25e6d3568259  2021-10-05
# 3  08/13/2021, 01:24:25  d7692c38-3963-59cf-b667-45958f297ea1  2021-09-10
# 4  08/13/2021, 01:24:25  ad4413a6-002a-53ca-8e72-26225d4dfb43  2021-10-05
#
#                                  job_type  \
# 0   Permanent Job,International,Full time
# 1   Permanent Job,International,Full time
# 2   Permanent Job,International,Full time
# 3  Permanent Job,Jobs for Women,Full time
# 4   Permanent Job,International,Full time
#
#                                         company_name qualifications  ...  \
# 0                              The HDFC Bank Limited            NaN  ...
# 1  FIS Global Business Solutions India Private Li...            NaN  ...
# 2                                 Standard Chartered            NaN  ...
# 3                        Kotak Mahindra Bank Limited            NaN  ...
# 4                                           NetSuite            NaN  ...
#
#            address_locality  address_region address_country postal_code  \
# 0                     Anjar         Gujarat              IN         NaN
# 1                     Noida   Uttar Pradesh              IN         NaN
# 2                    Mumbai     Maharashtra              IN         NaN
# 3               Other India     Other India              IN         NaN
# 4  Hyderabad / Secunderabad  Andhra Pradesh              IN         NaN
#
#   street_address         salary units  currency     experience  \
# 0            NaN  Not disclosed  P.A.       INR      1-3 years
# 1            NaN  Not disclosed  P.A.       INR  Not Specified
# 2            NaN  Not disclosed  P.A.       INR  Not Specified
# 3            NaN  Not disclosed  P.A.       INR     8-10 years
# 4            NaN  Not disclosed  P.A.       INR     7-10 years
#
#   months_of_experience
# 0                 12.0
# 1                  NaN
# 2                  NaN
# 3                 96.0
# 4                 84.0
#
# [5 rows x 24 columns]

# %%
df["clean_description"] = df["description"].fillna("").astype(str)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(
    max_features=1000,
    stop_words="english"
)

# %%
X = vectorizer.fit_transform(df["clean_description"])

# %%
terms = vectorizer.get_feature_names_out()
scores = X.sum(axis=0).A1

tfidf_keywords = sorted(
    zip(terms, scores),
    key=lambda x: x[1],
    reverse=True
)

tfidf_keywords[:20]
# Out:
# [('experience', np.float64(1131.890464510508)),
#  ('skills', np.float64(813.1875241175283)),
#  ('team', np.float64(659.4442631685821)),
#  ('business', np.float64(647.9294153272048)),
#  ('job', np.float64(628.816094865535)),
#  ('work', np.float64(620.0730120547214)),
#  ('customer', np.float64(593.9670881885453)),
#  ('management', np.float64(548.9434211614972)),
#  ('data', np.float64(546.9473692662575)),
#  ('knowledge', np.float64(537.0533467523722)),
#  ('good', np.float64(516.5252890285116)),
#  ('development', np.float64(492.45922403598377)),
#  ('sales', np.float64(489.56124687643006)),
#  ('design', np.float64(466.879744200094)),
#  ('years', np.float64(459.48514968297343)),
#  ('ensure', np.float64(450.69289712335035)),
#  ('description', np.float64(446.42284234553733)),
#  ('technology', np.float64(433.4375151092962)),
#  ('services', np.float64(409.544264713352)),
#  ('project', np.float64(408.497337014317))]

# %%
tfidf_keywords[:20]
# Out:
# [('experience', np.float64(1131.890464510508)),
#  ('skills', np.float64(813.1875241175283)),
#  ('team', np.float64(659.4442631685821)),
#  ('business', np.float64(647.9294153272048)),
#  ('job', np.float64(628.816094865535)),
#  ('work', np.float64(620.0730120547214)),
#  ('customer', np.float64(593.9670881885453)),
#  ('management', np.float64(548.9434211614972)),
#  ('data', np.float64(546.9473692662575)),
#  ('knowledge', np.float64(537.0533467523722)),
#  ('good', np.float64(516.5252890285116)),
#  ('development', np.float64(492.45922403598377)),
#  ('sales', np.float64(489.56124687643006)),
#  ('design', np.float64(466.879744200094)),
#  ('years', np.float64(459.48514968297343)),
#  ('ensure', np.float64(450.69289712335035)),
#  ('description', np.float64(446.42284234553733)),
#  ('technology', np.float64(433.4375151092962)),
#  ('services', np.float64(409.544264713352)),
#  ('project', np.float64(408.497337014317))]
